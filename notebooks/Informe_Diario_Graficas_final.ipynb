# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('seaborn-whitegrid')
import seaborn as sns

# %%
datos=pd.read_csv(r'./Backtesting/datos3.csv')
datos.columns
# Out:
# Index(['Stock', 'Tipo Operacion', 'Precio de Entrada', 'Fecha de Entrada',
#        'Precio de Salida', 'Fecha de Salida', 'Stop Loss', 'Riesgo:Beneficio',
#        'Estrategia', 'Ganada o Perdida', 'Dinero Ganado', 'Dinero Perdido',
#        'Spread Etoro ($)', 'Notas'],
#       dtype='object')

# %%
dinero_ganado_total=datos['Dinero Ganado'].sum()
dinero_perdido_total=datos['Dinero Perdido'].sum()
dinero_total=dinero_ganado_total-dinero_perdido_total
print('Dinero total:',dinero_total)
print('Dinero ganado:',dinero_ganado_total)
print('Dinero perdido:',dinero_perdido_total)
# Out:
# Dinero total: 0.0
# Dinero ganado: 3.0
# Dinero perdido: 3.0

# %%
dinero_perdido=datos['Dinero Perdido']*-1
fig = plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.bar(datos['Stock'],datos['Dinero Ganado'],color='green',width=0.5)
axes.bar(datos['Stock'],dinero_perdido,color='red',width=0.6)
axes.set_title('Relacion Victorias y Derrotas por Accion',fontsize=18,fontweight='bold')
axes.set_xlabel('Stock')
axes.set_ylabel('Dinero ($)')
axes.grid(color='grey', linestyle='dotted', linewidth=0.75)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ggarcia\AppData\Local\Temp\ipykernel_6880\2244240479.py:10: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
fig = plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])
sns.countplot(data=datos, x='Ganada o Perdida',ax=axes,palette='bright')
axes.set_title('Trades Ganados frente a los Perdidos',fontsize=18,fontweight='bold')
axes.set_xlabel('Ganada o Perdida')
axes.set_ylabel('Cuantos Trades')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ggarcia\AppData\Local\Temp\ipykernel_6880\3115075062.py:7: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
